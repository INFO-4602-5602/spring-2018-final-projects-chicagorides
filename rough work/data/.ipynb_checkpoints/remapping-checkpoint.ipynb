# %%
import pandas as pd
import json
import numpy as np

# %%
df =pd.read_csv("chicago_taxi_trips_2016_01.csv")

# %%
with open('column_remapping.json') as json_data:
    js = json.load(json_data)

# %%
# for row in df.iterrows():
df.columns
# Out:
# Index(['taxi_id', 'trip_start_timestamp', 'trip_end_timestamp', 'trip_seconds',
#        'trip_miles', 'pickup_census_tract', 'dropoff_census_tract',
#        'pickup_community_area', 'dropoff_community_area', 'fare', 'tips',
#        'tolls', 'extras', 'trip_total', 'payment_type', 'company',
#        'pickup_latitude', 'pickup_longitude', 'dropoff_latitude',
#        'dropoff_longitude'],
#       dtype='object')

# %%
import math
count = 0

change_params = ["pickup_latitude","pickup_longitude","dropoff_latitude","dropoff_longitude"]
for param in change_params:
    print("Current Param {}".format(param))
    for i in range(len(df)):
        try:
            if not math.isnan(df.at[i,param]):
                df.at[i,param] = js[param][str(int(df.at[i,param]))]
        except KeyError:
            print("[Error] Reading : {} and value of {} : {}".format(i, param , df.at[i,param]))
# Out:
# Current Param {}

# %%
df.head(100)
# Out:
#     taxi_id trip_start_timestamp  trip_end_timestamp  trip_seconds  \
# 0      85.0   2016-1-13 06:15:00  2016-1-13 06:15:00         180.0
# 1    2776.0   2016-1-22 09:30:00  2016-1-22 09:45:00         240.0
# 2    3168.0   2016-1-31 21:30:00  2016-1-31 21:30:00           0.0
# 3    4237.0   2016-1-23 17:30:00  2016-1-23 17:30:00         480.0
# 4    5710.0   2016-1-14 05:45:00  2016-1-14 06:00:00         480.0
# 5    1987.0    2016-1-8 18:15:00   2016-1-8 18:45:00        1080.0
# 6    4986.0   2016-1-14 04:30:00  2016-1-14 05:00:00        1500.0
# 7    6400.0   2016-1-26 04:15:00  2016-1-26 04:15:00          60.0
# 8    7418.0   2016-1-22 11:30:00  2016-1-22 11:45:00         180.0
# 9    6450.0    2016-1-7 21:15:00   2016-1-7 21:15:00           0.0
# 10   1078.0   2016-1-25 09:00:00  2016-1-25 09:00:00         480.0
# 11   6641.0    2016-1-6 23:15:00   2016-1-6 23:30:00         420.0
# 12    920.0   2016-1-13 18:30:00  2016-1-13 19:00:00        1380.0
# ...

# %%
df.to_csv("January.csv")
